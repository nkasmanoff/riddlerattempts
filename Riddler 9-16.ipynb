# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1.0, 1.0, 20)
y = np.linspace(-1.0, 1.0, 20)
X, Y = np.meshgrid(x,y)
F = X**2 + Y**2
plt.contour(X,Y,F,[0],'b')

# %%
x = np.linspace(-1, 1, 11)
y = []
yneg = []
for i in range(len(x)):
    y.append(np.sqrt(1-x[i]**2))
    yneg.append(-np.sqrt(1-x[i]**2))
plt.plot(x, y,'o')
plt.plot(x, yneg,'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y
# Out:
# [-1.0,
#  -0.60493827160493829,
#  -0.30864197530864201,
#  -0.11111111111111113,
#  -0.01234567901234569,
#  -0.01234567901234569,
#  -0.11111111111111106,
#  -0.30864197530864174,
#  -0.60493827160493807,
#  -1.0]
